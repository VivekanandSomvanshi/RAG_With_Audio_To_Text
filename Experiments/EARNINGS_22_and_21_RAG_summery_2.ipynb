# %%
# Core libraries
# !pip install langchain
# !pip install langchain-core
# !pip install sentence-transformers
# !pip install tiktoken
! pip install -U google-generativeai

# Large language models and vector stores
# !pip install openai  # Upgrade later if needed
# !pip install groq  # If using Groq for acceleration
# !pip install pinecone-client
# !pip install chromadb

# Langchain extensions and integrations
# !pip install langchain-community
# !pip install langchain-pinecone
# !pip install langchain-groq  # If using Groq

# Additional dependencies
# !pip install huggingface_hub

# Upgrades
# !pip install -U langchain-community
# !pip install --upgrade openai
# !pip install --upgrade langchain-pinecone
# !pip install -qU langchain-groq  # Quiet upgrade
# Out:
# Collecting langchain
#   Downloading langchain-0.2.14-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.32 (from langchain)
#   Downloading langchain_core-0.2.33-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.100-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.32->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.2.14-py3-none-any.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 39.1 MB/s eta 0:00:00
# Downloading langchain_core-0.2.33-py3-none-any.whl (391 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.5/391.5 kB 25.7 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.100-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 kB 10.3 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.6 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.6 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: tenacity, orjson, jsonpointer, h11, jsonpatch, httpcore, httpx, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.14 langchain-core-0.2.33 langchain-text-splitters-0.2.2 langsmith-0.1.100 orjson-3.10.7 tenacity-8.5.0
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.10/dist-packages (0.2.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (0.1.100)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core) (2.20.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (2.0.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.75->langchain-core) (1.2.2)
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 7.4 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers

# %%
from google.colab import userdata
KEY_groq = userdata.get('GROQ_API_KEY')
KEY_openai = userdata.get('OPENAI_API_KEY')
KEY_GOOGLE  = userdata.get('GOOGLE_API_KEY')

# %%
import os
import json
import datetime
import pandas as pd
import warnings

# NLP Libraries
import transformers
import torch

import os
import google.generativeai as genai

# Langchain Core
from langchain.schema import HumanMessage, AIMessage, ChatMessage
from langchain_core.tools import tool
from langchain_core.pydantic_v1 import BaseModel, Field

# Langchain LLMs and Agents
from langchain.llms import OpenAI, HuggingFacePipeline, CTransformers
from langchain.chat_models import ChatOpenAI
from langchain.agents import AgentType, load_tools, initialize_agent

# Langchain Chains and Prompts
from langchain.chains import LLMChain, SequentialChain, RetrievalQA, ConversationChain
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate, MessagesPlaceholder
from langchain_core.messages import SystemMessage

# Langchain Memory
from langchain.memory import ConversationBufferMemory, ConversationBufferWindowMemory

# Langchain Document Processing
from langchain.document_loaders import PyPDFLoader, DirectoryLoader, PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Langchain Embeddings and Vector Stores
from langchain.embeddings import HuggingFaceEmbeddings, OpenAIEmbeddings
from langchain.vectorstores import Pinecone

# Groq Integration (if used)
from groq import Groq
from langchain_groq import ChatGroq

# External Libraries
import pinecone

# %%
transcript_df = pd.read_csv('/content/drive/MyDrive/DataSets/Earnings_21.csv')

# %%
transcript_df.head(11)
# Out:
#     file_id  audio_length  sample_rate                company_name  \
# 0   4320211      3285.848        24000                   Monro Inc
# 1   4330115      2458.904        24000                    Culp Inc
# 2   4341191      5740.640        24000            General Electric
# 3   4344338      2721.169        44100                Danaher Corp
# 4   4344866      3275.456        24000                   Spire Inc
# 5   4346818      3972.022        11025              Ingersoll Rand
# 6   4346923      4709.418        16000              Cementos Argos
# 7   4359732      4887.498        44100  Kuehne Nagel International
# 8   4359971      3759.944        24000                 Constellium
# 9   4360366      3906.752        24000     Travelers Companies Inc
# 10  4360674      3595.023        11025          Nextera Energy Inc
#
#     financial_quarter            sector  speaker_switches  unique_speakers  \
# 0                   3    Consumer Goods                82               10
# 1                   3  Industrial Goods                43                8
# 2                   1      Conglomerate               147               14
# 3                   1      Conglomerate                51                7
# 4                   2         Utilities                82               10
# 5                   1  Industrial Goods                99               14
# 6                   1  Industrial Goods               120               20
# 7                   2          Services               114               13
# 8                   2  Industrial Goods               116               10
# 9                   2         Financial               104               15
# 10                  2         Utilities                43                9
#
#     curator_id                                      transcription
# 0            1  Good morning ladies and gentlemen, and welcome...
# 1            1  Good day and welcome to Culp's third quarter 2...
# 2            1  Good morning and welcome to the first quarter ...
# 3            1  My name is Christelle and I will be your confe...
# 4            8  Good morning, and welcome to the Spire Second ...
# 5            0  Ladies and gentlemen thank you for standing by...
# 6            1  Hello gentlemen, gent- ladies and gentlemen, a...
# 7            9  Ladies and gentlemen, welcome to Kuehne + Nage...
# 8            8  Ladies and gentlemen, thank you for standing b...
# 9            8  Good morning, ladies and gentlemen. Welcome to...
# 10           8  Good morning everyone, and welcome to the Next...

# %%
len(transcript_df['transcription'][0])
# Out:
# 50968

# %%
# model="llama-3.1-70b-versatile"
modelgroq = "llama-3.1-70b-versatile"

groq_chat = ChatGroq(groq_api_key=KEY_groq, model_name=modelgroq,temperature=0.3)

# %%
PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')

# %% [markdown]
# ### Summerizing The Transcription

# %%
# def summarize_text(text):
#     # Use Hugging Face model
#     summary = summarizer(text, max_length=500, min_length=400, do_sample=False)
#     return summary[0]['summary_text']

# %%
# # If using OpenAI's API for summarization:
# def summarize_text_openai(text):
#     response = openai.ChatCompletion.create(
#         model="gpt-4",
#         messages=[
#             {"role": "system", "content": "Summarize the following text to 400-500 words."},
#             {"role": "user", "content": text}
#         ]
#     )
#     return response['choices'][0]['message']['content']

# %%
# from groq import Groq

# # Set up Groq API key
# client = Groq(
#     api_key=KEY_groq,  # Replace with your actual API key
#     # api_key=os.environ.get("GROQ_API_KEY"),
# )

# # Function to summarize using Groq
# def summarize_text_groq(text):
#     chat_completion = client.chat.completions.create(
#         messages=[
#             {
#                 "role": "user",
#                 "content": f"Summarize the following text into 400-500 words:\n\n{text}",
#             }
#         ],
#         model = "llama-3.1-70b-versatile",
#     )
#     return chat_completion.choices[0].message.content

# %%
import os
import time  # For adding delay
import pandas as pd
from groq import Groq

# Set up Groq API key
client = Groq(
    api_key=KEY_groq,  # Replace with your actual API key
)

# Function to summarize using Groq
def summarize_text_groq(text):
    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": f"Summarize the following text into 400-500 words:\n\n{text}",
                }
            ],
            model = "llama-3.1-70b-versatile",  # Replace with the correct model
        )
        return chat_completion.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
# Initialize an empty list to store summaries
summaries = []

# Loop through each row, process one by one
for index, row in transcript_df.head(11).iterrows():  # Process first 11 rows
    print(f"Processing row {index + 1} with file_id {row['file_id']}...")  # Print statement to show progress

    summary = summarize_text_groq(row['transcription'])

    if summary:
        summaries.append({'file_id': row['file_id'], 'summary': summary})
        print(f"Successfully summarized file_id {row['file_id']}.")
    else:
        print(f"Failed to summarize file_id {row['file_id']}.")

    # Add a delay to avoid overwhelming the API
    time.sleep(120)  # Delay for 2 seconds (adjust as needed)
    print("sleep for 2 minutes")
# Out:
# Processing row 1 with file_id 4320211...
# Successfully summarized file_id 4320211.
# sleep for 2 minutes
# Processing row 2 with file_id 4330115...
# Successfully summarized file_id 4330115.
# sleep for 2 minutes
# Processing row 3 with file_id 4341191...
# Successfully summarized file_id 4341191.
# sleep for 2 minutes
# Processing row 4 with file_id 4344338...
# Successfully summarized file_id 4344338.
# sleep for 2 minutes
# Processing row 5 with file_id 4344866...
# Successfully summarized file_id 4344866.
# sleep for 2 minutes
# Processing row 6 with file_id 4346818...
# Successfully summarized file_id 4346818.
# sleep for 2 minutes
# Processing row 7 with file_id 4346923...
# Successfully summarized file_id 4346923.
# sleep for 2 minutes
# Processing row 8 with file_id 4359732...
# Successfully summarized file_id 4359732.
# sleep for 2 minutes
# Processing row 9 with file_id 4359971...
# Successfully summarized file_id 4359971.
# sleep for 2 minutes
# Processing row 10 with file_id 4360366...
# Successfully summarized file_id 4360366.
# sleep for 2 minutes
# Processing row 11 with file_id 4360674...
# Successfully summarized file_id 4360674.
# sleep for 2 minutes

# %%
summaries
# Out:
# [{'file_id': 4320211,
#   'summary': "Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0.9% decline in comparable store sales, primarily due to mild winter weather conditions in the Northeast and Midwest. Despite this, the company remains confident in its Monro Forward strategy, which includes store rebranding and re-imaging, technological investments, and optimization of its tire category management.\n\nThe company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales. The company has also made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.\n\nMonro Inc. has also made significant progress in its acquisitions, with the company announcing the acquisition of three companies with a total of 23 locations. The company expects these acquisitions to add approximately $45 million in annualized sales.\n\nThe company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather. The company now expects comparable store sales to be down 1% to flat, with total sales expected to be in the range of $1.027 billion to $1.029 billion.\n\nThe company's CEO, Brett Ponton, stated that the company is committed to driving the necessary changes to improve its business and is confident in its ability to execute its strategy. The company's CFO, Brian D'Ambrosia, noted that the company's guidance assumes relatively stable overall tire and oil costs for the balance of fiscal 2020.\n\nDuring the Q&A session, analysts asked questions about the company's store rebranding and re-imaging initiative, its technological investments, and its acquisitions. The company's management provided additional color on these topics, including the expected timeline for the rollout of its new tire category management system and the expected impact of the mild winter weather on its business.\n\nOverall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders. The company's stock price has been impacted by the mild winter weather, but the company's management believes that its strategy will ultimately drive growth and profitability.\n\nKey points from the call include:\n\n* Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions.\n* The company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales.\n* The company has made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.\n* The company has announced the acquisition of three companies with a total of 23 locations, which are expected to add approximately $45 million in annualized sales.\n* The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather, with comparable store sales expected to be down 1% to flat and total sales expected to be in the range of $1.027 billion to $1.029 billion.\n\nOverall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders."},
#  {'file_id': 4330115,
#   'summary': "Culp, Inc. hosted a conference call to discuss its third quarter 2020 earnings results. The call featured Iv Culp, Chief Executive Officer; Ken Bowling, Chief Financial Officer; and Boyd Chumbley, President of the upholstery fabrics business.\n\nThe company reported a net loss of $5.1 million for the third quarter, compared to a pre-tax income of $4.3 million for the same period last year. The results were affected by a reversal of a $6.1 million recorded contingent earn-out liability and non-cash impairment charges of $13.6 million related to the home accessory division.\n\nCulp's global platform is seen as a distinct competitive advantage, allowing the company to quickly respond to changing market dynamics. The company is also benefiting from significant synergies across its business segments, fostering collaboration and product development.\n\nDespite the challenges in the mattress fabrics business, the company remains focused on creative designs, innovative products, and exceptional service. The upholstery fabrics business was affected by a slowdown in shipments heading into the Chinese New Year holiday, but the company is pleased with its overall performance.\n\nThe home accessories segment, which includes the company's e-commerce and finished products business, reported an operating loss for the quarter. However, the company is encouraged by recent opportunities with new online marketplaces and business-to-business sales channels.\n\nThe company is working to refine its strategy and drive improved results for its home accessories segment. This includes developing new products featuring Culp mattress fabrics and upholstery fabrics, and improving its performance on Amazon.\n\nCulp is also expanding its capabilities in Vietnam and Haiti, with a focus on mattress fabrics and sewn covers. The company expects to add fabric production capabilities in Vietnam this calendar year and is expanding its sewn cover production capabilities in Haiti with a new building and additional equipment.\n\nThe company's outlook for the fourth quarter assumes that the Coronavirus outbreak does not have a greater-than-anticipated impact on its operations. However, the potential impact of the Coronavirus is difficult to estimate reasonably at this point.\n\nCulp expects overall sales to decrease slightly compared to the fourth quarter of last year, with mattress fabric sales expected to be slightly down due to continuing market pressure and softness in its legacy business. Operating income and margins are expected to increase slightly compared to the prior period.\n\nIn the upholstery fabric segment, the company expects fourth-quarter sales and operating income and margins to be slightly higher than the prior year period. In the home accessory segment, the company expects fourth-quarter sales to be comparable to the fourth quarter of last fiscal year, with an operating loss expected but with significant improvement compared to the prior year period.\n\nCulp's expectations for the fourth quarter are subject to a high degree of uncertainty due to the Coronavirus outbreak and its potential impact on consumer confidence and market conditions. The company is closely monitoring the situation and is prepared to adjust its business strategy and operations as needed.\n\nThe call concluded with a question-and-answer session, during which the company's executives provided additional information and insights on its business operations and outlook."},
#  {'file_id': 4341191,
#   'summary': "Given the extensive nature of the text provided, summarizing it into 400-500 words will necessitate omitting certain details while focusing on the core message, key points, and the overall structure of the General Electric Company's first quarter 2020 earnings conference call discussion:\n\nSummary -\n\n-This version unfortunately exists unseen where corporate web events review financially - health records businesses inside USA into sound progress numbers recovery this summally growing near side since bad into bigger really taking impacts-\n\n An. online was once morning hosting invited its reviewing finances being important side than important parts work leading impacts changing ways been operating next back every two current trying use whole view bad during forward keeping made safety full about opening sound our different environment are kind thanks l with about at biggest welcome general hope event called would healthy management steps period at there look looking view COVID.scalablytyped at trying operating models open market around across always key inside same actions key progress there talking ongoing hard down stay real changed areas high forward clearly coming then same people turn customers tough go clearly significant put top they should together past done by come model end together do less moving \n\nge even lower parts industry by while impacts up remain was ge moving expect make money industrial continue bad expected model focus run being inside can power those few most tough impacted taking it - do years free higher been done progress operating side which use service want safety head world having how quickly whole coming major today half growing lot turn businesses important area balance here running market financial most. best interest point times do head environment put remain use quarter which trying give hope impacted after together inside side had low hope customers last open full around seeing in having trying during has moved number significant cost talk think total ongoing last financial every customers changed steps strong growing way parts  out growing how leading industrial some many some for always say progress low taking into there expect together here so better point significant which may past areas impacts around will come model point back really full with company clearly also impacts that top as around next area customers COVID stay area more use service said now next biggest while focus bad ongoing ge down major all running side period said big looking keep and after into about."},
#  {'file_id': 4344338,
#   'summary': "Danaher Corporation's first quarter 2020 earnings conference call took place, led by conference facilitator Christelle and featuring Tom Joyce, President and CEO, and Matt McGrew, Executive Vice President and CFO. The call began with a welcome and introduction, followed by a review of the company's earnings release, slide presentation, and other relevant materials available on the investor section of the Danaher website.\n\nTom Joyce started by acknowledging the challenges posed by the COVID-19 pandemic and expressing gratitude to Danaher's associates, suppliers, and business partners for their efforts in responding to the crisis. He highlighted the company's position of strength, with a resilient portfolio of businesses, a talented team, and the Danaher Business System (DBS) as its driving force.\n\nJoyce then discussed the company's innovative solutions that are part of the direct response to COVID-19, including IDT's primer and probe kits, Cepheid's rapid molecular test, and Beckman Coulter's antibody assays. He also mentioned the company's support for biotech researchers and manufacturers working on COVID-19 vaccines and therapies, through Pall's filtration solutions and Cytiva's prototype affinity resins.\n\nThe call then shifted to a review of the company's first quarter results, with sales growing 3% to $4.3 billion, driven by 4.5% core revenue growth. The impact of foreign currency translation decreased revenues by 1.5%. Gross profit margin was 56.2%, and operating profit margin was 16.1%. Adjusted diluted net earnings per common share were $1.05.\n\nJoyce also discussed the company's outlook for the second quarter, with core revenue growth expected to be in the range of flat to down 10%. He noted that the company is well-positioned to navigate the uncertain environment, with a strong portfolio, exceptional team, and DBS-driven execution.\n\nThe call concluded with a question-and-answer session, during which Joyce and McGrew addressed various topics, including the company's COVID-19 response, the integration of Cytiva, and the outlook for the environmental and applied solutions segment.\n\nIn his final remarks, Joyce reflected on his decision to retire as CEO, effective September 1, 2020, and expressed confidence in the company's future under the leadership of Rainer Blair, who will succeed him as CEO. Joyce also thanked his colleagues and the Danaher team for their support and hard work over the years.\n\nOverall, the call provided an update on Danaher's performance and outlook, as well as insights into the company's response to the COVID-19 pandemic and its plans for the future."},
#  {'file_id': 4344866,
#   'summary': "The Spire Second Quarter Earnings call began with a welcome from Scott Dudley, Managing Director of Investor Relations. He introduced the presenters, Suzanne Sitherwood, President and CEO, Steve Lindsey, Executive Vice President and Chief Operating Officer, and Steve Rasche, Executive Vice President and CFO.\n\nSuzanne Sitherwood started by acknowledging the challenges posed by the COVID-19 pandemic and expressing her gratitude to the employees for their hard work and dedication. She highlighted the company's mission to answer every challenge, advance every community, and enrich every life through the strength of their energy.\n\nSuzanne discussed the company's response to the pandemic, including the activation of their incident support team and crisis management team. She also mentioned the company's efforts to support their customers, including the suspension of involuntary disconnections and late fees, and the expansion of customer bill assistance programs.\n\nSteve Lindsey provided an update on the company's operations and response to the pandemic. He discussed the company's efforts to protect their employees, customers, and communities, including the implementation of safety protocols and the provision of personal protective equipment.\n\nSteve Rasche presented the company's financial results, including a decline in net economic earnings due to warmer weather and losses on investments. He also discussed the company's capital spending plans, including an increase in investment in new business and infrastructure upgrades.\n\nThe presenters also discussed the company's regulatory efforts, including their pursuit of favorable regulatory outcomes in Missouri and Alabama. They mentioned the company's efforts to clarify the ISRS statute and to obtain approval for their infrastructure upgrade plans.\n\nDuring the Q&A session, the presenters answered questions from analysts and investors on various topics, including the company's response to the pandemic, their capital spending plans, and their regulatory efforts.\n\nIn summary, the Spire Second Quarter Earnings call provided an update on the company's operations, financial results, and regulatory efforts. The presenters highlighted the company's commitment to their customers, employees, and communities, and their efforts to navigate the challenges posed by the COVID-19 pandemic.\n\nKey points from the call include:\n\n* The company's net economic earnings declined due to warmer weather and losses on investments.\n* The company is increasing its investment in new business and infrastructure upgrades.\n* The company is pursuing favorable regulatory outcomes in Missouri and Alabama.\n* The company is committed to supporting their customers, employees, and communities during the pandemic.\n* The company's capital spending plans include an increase in investment in new business and infrastructure upgrades.\n\nOverall, the call provided a comprehensive update on the company's performance and outlook, and highlighted their commitment to their stakeholders."},
#  {'file_id': 4346818,
#   'summary': "The conference call transcript is from Ingersoll Rand's first quarter 2020 earnings call, which took place on May 2020. The call began with an introduction by the Head of Investor Relations, Vik Kini, and then covered various topics including the company's performance during the COVID-19 pandemic, the benefits of the merger between Ingersoll Rand and Gardner Denver, and the company's strategy for cost savings and margin improvement.\n\nIngersoll Rand's CEO, Vicente Reynal, mentioned that the company's response to the pandemic has been swift and focused on two key areas: health and safety and business continuity. The company activated its COVID-19 response plan in February and implemented enhanced safety protocols and a work-from-home policy for employees who can work remotely.\n\nReynal also discussed the company's cost savings plan, which includes a synergy funnel of over $350 million, with increases across all major savings categories. The company has already realized $90 million in annualized structural cost reductions and expects to deliver approximately 35% of its overall synergy target in 2020.\n\nIn terms of financial performance, the company reported a decline in revenue of 14% in the first quarter, primarily due to the impact of the pandemic. However, the company's adjusted EBITDA margin was 16.4%, down 200 basis points from last year. The company also reported a decline in free cash flow due to the impact of the pandemic on its supply chain and operations.\n\nReynal emphasized that the company's commitment to its long-term strategy remains unwavering and that it will continue to invest in growth initiatives and execute on its cost savings plan.\n\nDuring the Q&A session, analysts asked questions about the company's decremental margins, cost savings plan, and the impact of the pandemic on its supply chain and operations. Reynal provided additional color on these topics and emphasized the company's commitment to managing costs and improving its margin performance.\n\nOverall, the call provided an update on Ingersoll Rand's performance during a challenging time and highlighted the company's efforts to navigate the pandemic and execute on its long-term strategy.\n\nHere are the key takeaways from the call:\n\n* Ingersoll Rand's response to the COVID-19 pandemic has been swift and focused on two key areas: health and safety and business continuity.\n* The company has a synergy funnel of over $350 million, with increases across all major savings categories.\n* The company has already realized $90 million in annualized structural cost reductions and expects to deliver approximately 35% of its overall synergy target in 2020.\n* The company's adjusted EBITDA margin was 16.4%, down 200 basis points from last year.\n* The company reported a decline in free cash flow due to the impact of the pandemic on its supply chain and operations.\n* The company's commitment to its long-term strategy remains unwavering, and it will continue to invest in growth initiatives and execute on its cost savings plan."},
#  {'file_id': 4346923,
#   'summary': 'The conference call discussed the first quarter 2020 earnings of Cementos Argos, a Colombian cement company. The call was hosted by Indira Diaz, and featured Juan Esteban Calle, CEO, Carlos Yusty, CFO, and other executives.\n\nThe company reported a 6.1% decrease in cement dispatches and a 10.7% decrease in ready-mix dispatches compared to the same quarter of 2019. Revenues closed at 2.2 trillion Pesos, with a 0.2% increase on a year-to-year basis, mainly due to the devaluation of the Colombian peso. EBITDA decreased by 1% on a like-for-like basis.\n\nThe company\'s U.S. division reported a slight decrease in cement dispatches, with low single-digit growth in the deep South and Florida. The ready-mix business experienced a 5.5% decrease on a like-for-like basis, mainly due to adverse weather conditions.\n\nIn Colombia, the company reported a 13.9% decrease in cement dispatches and a 19.5% decrease in ready-mix dispatches. However, the company was able to continue dispatching to essential infrastructure projects during the quarantine.\n\nThe company\'s Caribbean and Central America division reported a decrease in volumes due to the COVID-19 crisis, but expects a rebound in the second half of the year.\n\nThe company\'s liquidity position is strong, with a cash position of approximately 615 billion Pesos as of April 30. The company has also taken steps to reduce its capital expenditures by $40 million and has renegotiated supply contracts to reduce costs.\n\nThe company\'s Preset program, which stands for "Restart, Safe and Healthy to Boost the Economy, Bring Hope and Transform Lives," aims to operate the company during the pandemic and the subsequent gradual market recovery. The program focuses on three dimensions: health and safety, liquidity, and operational excellence.\n\nThe company\'s executives expressed confidence in the company\'s ability to navigate the current market conditions and to continue building on its strengths in the region.\n\nIn terms of competitive dynamics, the company reported a significant decline in cement and clinker imports in Colombia, and expects this trend to continue. The company also reported a decline in imports in Panama and Honduras.\n\nThe company\'s energy costs are expected to be lower in the second half of the year, due to lower commodity prices. The company\'s reset initiative does not include the benefits of lower energy costs, which will be on top of the reset numbers.\n\nThe company\'s working capital requirements are being closely managed, with a focus on controlling purchases and reducing inventory levels.\n\nOverall, the company\'s executives expressed confidence in the company\'s ability to navigate the current market conditions and to continue building on its strengths in the region.'},
#  {'file_id': 4359732,
#   'summary': "Here's a 400-500 word summary of Kuehne + Nagel's Half Year 2020 Results conference call:\n\nDr. Detlef Trefzger, CEO, welcomed everyone and highlighted that Kuehne + Nagel had managed to deliver excellent service during the pandemic while handling a high demand for essential goods. This has resulted in market share gains across all business units. Dr. Trefzger highlighted four key financial figures:\n\n- Net turnover decreased by 7.5%, significantly influenced by the negative exchange effect (5.90%) on revenue and -9.1% and a decreased volume impact. (-8% during 1HY vs- last 10%, see from current spot reater EBIT significantly over compensated \n\nFinancial information. To remain anonymous then Mr: this you put re after now while their call . Some even business remain CEO highlights\nHere just but overall   important- those number good growth better best many know  \n\nHighlight Group but during there units remained steady logistics no single exception due can large first huge profit part sea port overall financial full said volumes performance through loss be reduced re did positive normal below financial port period there two there years months later really came new . well less them K + of can like negative part Nagel much much biggest before Nagel four when due these high drop low + which volume per   , result despite cargo half head freight units it despite are before know growth years next did next came CEO (period market were Sea ) overall increase other freight next out low Logistics Group only even sea single three financial \ndr high less these will biggest ever up back which rate single ever less strong like Logistics Logistics profit higher increase we. by market two time part - their months E that same higher Nagel our years positive , freight E ever very result significant   e what loss new re head quarter some large still quarter has as better did did normal there volumes so during through air quarter higher now ever volume then really on ever or overall cargo much four market increase second all strong strong due two see over higher are despite at part is were \n\nOver other drop with which last   normal large. came still those less re had biggest best big them negative years \nback sea quarter CEO only volume (3 which years full well had E biggest very biggest \n\nThose well volumes new it , . - per two they financial still when months Nagel no unit   Sea due can much before Sea through half now with will due for volumes biggest through from so one increase despite period same next better very said is more years had what one like up years result second out Logistics result business business huge time by before other did did per + has have just volumes E negative logistics positive all E K really   quarter know strong two growth only are Logistics these less months better one higher very still biggest there four one all came less of as two \nprofit two cargo be during cargo single less our were are like now still Sea low four positive re, part re last strong came said single not result can half months good Air on is in \n\nKey Results figures stated :\n-Gross Profit lower rate overall not however operational period decrease decrease Q down versus- strong their it performance those there market now years much will biggest higher air years head can part volume   did head however full all which or new came part out growth can they volume them then + all volume however than growth four sea better . before part normal over during ever despite our only new next for no we during units next Logistics came however   single part so increase result first during had.  \n-given- e if biggest also Nagel higher did which sea even , e bigger up sea on really time Nagel other were see these Sea growth sea despite quarter overall two is ( negative positive \n\nAccording  have key up only less through Group before just less be however years due two with three some high low well financial well result still which incr ...
#  {'file_id': 4359971,
#   'summary': "Constellium reported its second-quarter earnings, highlighting the company's ability to navigate through the COVID-19 pandemic. The company's shipment volumes decreased by 25% compared to the same quarter last year, and revenue decreased by 33%. However, the company's cost-control measures and flexible business model helped to mitigate the impact of the pandemic.\n\nConstellium's CEO, Jean-Marc Germain, stated that the company's priority is the health and safety of its employees, and they have implemented various initiatives to protect them. The company also reduced its costs and capital expenditures, with a 40% of its workforce on some type of partial unemployment or temporary layoff scheme during the quarter.\n\nThe company's adjusted EBITDA decreased by 51% compared to the same quarter last year, but its free cash flow was negative €33 million in the second quarter. However, the company expects to generate positive free cash flow in 2020 based on its current view of market conditions.\n\nConstellium's packaging business was impacted by the pandemic, with shipment volumes down 11% compared to the same quarter last year. However, the company is seeing strong demand in North America and stable demand in Europe. The company's aerospace business was also impacted, with shipment volumes down 40% compared to the same quarter last year.\n\nThe company's automotive business was severely impacted by the pandemic, with shipment volumes down 50% compared to the same quarter last year. However, the company is seeing a recovery in demand, with utilization rates increasing to above 80%.\n\nConstellium's CEO also highlighted the company's focus on sustainability, noting that the company has made progress in reducing its greenhouse gas emissions and improving its energy efficiency. The company has also been recognized for its sustainability achievements, receiving ASI certifications and an ESG rating of AA from MSCI.\n\nDuring the Q&A session, analysts asked questions about the company's cost-control measures, its outlook for the second half of the year, and its sustainability initiatives. The company's CEO and CFO provided detailed answers to these questions, highlighting the company's efforts to navigate through the pandemic and build a stronger company for the future.\n\nIn terms of the auto market, the company's CEO noted that the market is still fragile, but the company is seeing a recovery in demand. The company's customers are getting more confident in their ability to stay online, and the company is seeing a stronger rebound in Europe.\n\nOverall, Constellium's second-quarter earnings report highlighted the company's ability to navigate through the pandemic and its focus on building a stronger company for the future. The company's cost-control measures and flexible business model have helped to mitigate the impact of the pandemic, and the company is seeing a recovery in demand in its automotive and packaging businesses."},
#  {'file_id': 4360366,
#   'summary': "The Travelers Companies, Inc. held a conference call to discuss their second-quarter results for 2020. The company reported a small net loss due to high catastrophe losses and a loss in their non-fixed income investment portfolio. However, their underlying underwriting income was $572 million, up $254 million from the prior year quarter, benefiting from solid net earned premium and a 3.5-point improvement in the underlying combined ratio to 91.4%.\n\nThe COVID-19 pandemic had a modest net impact on their underwriting results, with $114 million of direct losses and $63 million of audit premium adjustments, which were offset by initial estimates of favorable loss activity. The company took a cautious approach to recognizing the net impact of COVID-19 related loss activity.\n\nIn terms of business insurance, the company achieved strong renewal rate change of 7.4%, the highest level since 2013, and close to the record level achieved in that year. Excluding workers' compensation, renewal rate change was double digits. Retention levels remained strong, and new business was down 10% from the prior year quarter.\n\nIn bond and specialty insurance, net written premiums increased by 3%, driven by strong growth in management liability and international businesses. The company's domestic management liability business achieved record renewal rate change while maintaining strong retention.\n\nIn personal insurance, excluding premium refunds, net written premiums increased by 6%, driven by strong retention and new business in both agency auto and agency homeowners. The company's agency homeowners business delivered another very strong quarter with retention of 87%, renewal premium change of 7.7%, and a 17% increase in new business.\n\nThe company's top line was resilient, with net written premiums increasing by 2% excluding premium refunds and personal insurance. The company expects to experience the impacts of economic disruption, but the extent and duration of the negative economic impacts related to the pandemic will depend on various factors.\n\nIn terms of operating expenses, results were adversely impacted by modest increases in the allowance for bad debt and the accrual for supplemental commissions. However, these expense increases were roughly offset by lower expenses in other categories.\n\nThe company's investment portfolio was impacted by the COVID-19 pandemic, with after-tax net investment income decreasing by 54% from the prior year quarter to $251 million. The decrease was driven by non-fixed income returns, where results for private equity, hedge fund, and real estate partnerships are generally reported on a one-quarter lag.\n\nThe company's capital management strategy remains unchanged, with a focus on holding onto a little more capital due to ongoing economic uncertainty and hurricane season. The company returned $218 million of capital to shareholders in the quarter via dividends and did not repurchase any shares.\n\nOverall, the company is well-positioned to navigate through the uncertain times and continue to serve their customers and agent and broker partners. They are confident in their ability to continue to succeed through these uncertain times and to benefit from the strength of their franchise as the economy recovers."},
#  {'file_id': 4360674,
#   'summary': "The conference call discussed the second quarter 2020 results of NextEra Energy, Inc. and NextEra Energy Partners. The company reported strong financial and operational performance, despite the challenges posed by the COVID-19 pandemic. Here are the key highlights from the call:\n\n1. **Strong Financial Performance**: NextEra Energy reported adjusted earnings per share (EPS) of $2.61, a 6-8% increase from the same period last year. The company also reported a 23% increase in adjusted EBITDA and a 46% increase in cash available for distribution.\n\n2. **Renewable Energy Growth**: NextEra Energy's renewable energy business, Energy Resources, reported a 14% increase in adjusted EPS. The company added 1,730 megawatts to its backlog, including 708 megawatts of wind, 844 megawatts of solar, and 178 megawatts of battery storage.\n\n3. **Hydrogen Pilot Project**: NextEra Energy announced a $65 million pilot project to produce green hydrogen at its Okeechobee Clean Energy Center. The project will utilize solar energy to produce hydrogen, which will be used to replace natural gas in one of the company's gas turbines.\n\n4. **M&A Opportunities**: NextEra Energy's CEO, Jim Robo, expressed interest in pursuing M&A opportunities, particularly in the Midwest and Southeast regions. He also mentioned that the company is looking at opportunities in Texas, despite the recent setback with the Oncor deal.\n\n5. **Rate Cases**: NextEra Energy plans to file for a combined rate case in early 2021 for its Florida utilities, FPL and Gulf Power. The company is confident in its ability to invest in these utilities and provide value to its customers.\n\n6. **Cost Management**: NextEra Energy has been a leader in cost management, with a focus on continuous improvement and innovation. The company believes that it can continue to reduce costs and improve efficiency, but acknowledges that it will require ongoing effort and creativity.\n\n7. **ESG Report**: NextEra Energy will publish its updated ESG report next week, which will include reporting under the Sustainability Accounting Standards Board (SASB) disclosures. The company is committed to sustainability and has been focused on ESG issues for over 25 years.\n\nOverall, the conference call highlighted NextEra Energy's strong financial and operational performance, its commitment to renewable energy growth, and its focus on innovation and cost management. The company is well-positioned for long-term growth and is confident in its ability to deliver value to its customers and shareholders."}]

# %%
# Convert summaries to a DataFrame
summary_df = pd.DataFrame(summaries)

# Save the summary DataFrame to a CSV file
summary_df.to_csv('/content/drive/MyDrive/DataSets/Earnings_21_summarized_transcriptions.csv', index=False)

# %%
summary_df = pd.read_csv('/content/drive/MyDrive/DataSets/Earnings_21_summarized_transcriptions.csv')

# %%
# # Apply summarization function
# transcript_df['summary'] = transcript_df['transcription'].apply(summarize_text_groq)  # or summarize_text_openai

# %%
summary_df
# Out:
#     file_id                                            summary
# 0   4320211  Monro Inc. held its third-quarter earnings con...
# 1   4330115  Culp, Inc. hosted a conference call to discuss...
# 2   4341191  Given the extensive nature of the text provide...
# 3   4344338  Danaher Corporation's first quarter 2020 earni...
# 4   4344866  The Spire Second Quarter Earnings call began w...
# 5   4346818  The conference call transcript is from Ingerso...
# 6   4346923  The conference call discussed the first quarte...
# 7   4359732  Here's a 400-500 word summary of Kuehne + Nage...
# 8   4359971  Constellium reported its second-quarter earnin...
# 9   4360366  The Travelers Companies, Inc. held a conferenc...
# 10  4360674  The conference call discussed the second quart...

# %%
len(summary_df['summary'][0])
# Out:
# 3424

# %%
summary_df['summary'][8]
# Out:
# "Constellium reported its second-quarter earnings, highlighting the company's ability to navigate through the COVID-19 pandemic. The company's shipment volumes decreased by 25% compared to the same quarter last year, and revenue decreased by 33%. However, the company's cost-control measures and flexible business model helped to mitigate the impact of the pandemic.\n\nConstellium's CEO, Jean-Marc Germain, stated that the company's priority is the health and safety of its employees, and they have implemented various initiatives to protect them. The company also reduced its costs and capital expenditures, with a 40% of its workforce on some type of partial unemployment or temporary layoff scheme during the quarter.\n\nThe company's adjusted EBITDA decreased by 51% compared to the same quarter last year, but its free cash flow was negative €33 million in the second quarter. However, the company expects to generate positive free cash flow in 2020 based on its current view of market conditions.\n\nConstellium's packaging business was impacted by the pandemic, with shipment volumes down 11% compared to the same quarter last year. However, the company is seeing strong demand in North America and stable demand in Europe. The company's aerospace business was also impacted, with shipment volumes down 40% compared to the same quarter last year.\n\nThe company's automotive business was severely impacted by the pandemic, with shipment volumes down 50% compared to the same quarter last year. However, the company is seeing a recovery in demand, with utilization rates increasing to above 80%.\n\nConstellium's CEO also highlighted the company's focus on sustainability, noting that the company has made progress in reducing its greenhouse gas emissions and improving its energy efficiency. The company has also been recognized for its sustainability achievements, receiving ASI certifications and an ESG rating of AA from MSCI.\n\nDuring the Q&A session, analysts asked questions about the company's cost-control measures, its outlook for the second half of the year, and its sustainability initiatives. The company's CEO and CFO provided detailed answers to these questions, highlighting the company's efforts to navigate through the pandemic and build a stronger company for the future.\n\nIn terms of the auto market, the company's CEO noted that the market is still fragile, but the company is seeing a recovery in demand. The company's customers are getting more confident in their ability to stay online, and the company is seeing a stronger rebound in Europe.\n\nOverall, Constellium's second-quarter earnings report highlighted the company's ability to navigate through the pandemic and its focus on building a stronger company for the future. The company's cost-control measures and flexible business model have helped to mitigate the impact of the pandemic, and the company is seeing a recovery in demand in its automotive and packaging businesses."

# %% [markdown]
# ### Chunking And Converting To Embeddings

# %%
#Create text chunks
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 20)
    # text_chunks = text_splitter.split_documents(extracted_data)
    text_chunks = text_splitter.split_text(extracted_data)

    return text_chunks

# %%
# # Assuming you already have `summary_df`
# # Initialize an empty list to store chunked data
# chunked_data_1 = []

# # Loop through each row in `summary_df`
# for index, row in summary_df.iterrows():
#     file_id = row['file_id']
#     summary = row['summary']

#     # Create text chunks
#     chunks = text_split(summary)

#     # Create a dictionary for each row and append to `chunked_data`
#     chunked_row = {'file_id': file_id}
#     for i, chunk in enumerate(chunks):
#         chunked_row[f'chunk_{i+1}'] = chunk

#     chunked_data.append(chunked_row)

# Apply text splitting to each summary and store chunks in a single column
summary_df['chunks'] = summary_df['summary'].apply(text_split)

# Save the DataFrame with chunks as lists
summary_df.to_csv('/content/drive/MyDrive/DataSets/Earnings_21_summary_with_chunks.csv', index=False)

# %%
file_id = summary_df['file_id'][1]
summarystr = summary_df['summary'][0]
chunks_1 = text_split(summarystr)

# %%
len(chunks_1)
# Out:
# 10

# %%
for chunk in chunks_1:
  print(len(chunk))
  print(chunk)
# Out:
# 416
# Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0.9% decline in comparable store sales, primarily due to mild winter weather conditions in the Northeast and Midwest. Despite this, the company remains confident in its Monro Forward strategy, which includes store rebranding and re-imaging, technological investments, and optimization of its tire category management.
# 372
# The company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales. The company has also made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.
# 252
# Monro Inc. has also made significant progress in its acquisitions, with the company announcing the acquisition of three companies with a total of 23 locations. The company expects these acquisitions to add approximately $45 million in annualized sales.
# 257
# The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather. The company now expects comparable store sales to be down 1% to flat, with total sales expected to be in the range of $1.027 billion to $1.029 billion.
# 339
# The company's CEO, Brett Ponton, stated that the company is committed to driving the necessary changes to improve its business and is confident in its ability to execute its strategy. The company's CFO, Brian D'Ambrosia, noted that the company's guidance assumes relatively stable overall tire and oil costs for the balance of fiscal 2020.
# 392
# During the Q&A session, analysts asked questions about the company's store rebranding and re-imaging initiative, its technological investments, and its acquisitions. The company's management provided additional color on these topics, including the expected timeline for the rollout of its new tire category management system and the expected impact of the mild winter weather on its business.
# 352
# Overall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders. The company's stock price has been impacted by the mild winter weather, but the company's management believes that its strategy will ultimately drive growth and profitability.
#
# Key points from the call include:
# 473
# * Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions.
# * The company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales.
# * The company has made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.
# 413
# * The company has announced the acquisition of three companies with a total of 23 locations, which are expected to add approximately $45 million in annualized sales.
# * The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather, with comparable store sales expected to be down 1% to flat and total sales expected to be in the range of $1.027 billion to $1.029 billion.
# 141
# Overall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders.

# %%
# # Convert chunked data to a DataFrame
# chunked_df = pd.DataFrame(chunked_data)

# # Save the chunked DataFrame to a CSV file
# chunked_df.to_csv('/content/drive/MyDrive/DataSets/Earnings_21_chunked_summaries.csv', index=False)

# %%
# summary_df_chunks = pd.read_csv('/content/drive/MyDrive/DataSets/Earnings_21_summary_with_chunks.csv')

# %%
# summary_df_chunks.head()
# Out:
#    file_id                                            summary  \
# 0  4320211  Monro Inc. held its third-quarter earnings con...
# 1  4330115  Culp, Inc. hosted a conference call to discuss...
# 2  4341191  Given the extensive nature of the text provide...
# 3  4344338  Danaher Corporation's first quarter 2020 earni...
# 4  4344866  The Spire Second Quarter Earnings call began w...
#
#                                               chunks
# 0  ['Monro Inc. held its third-quarter earnings c...
# 1  ['Culp, Inc. hosted a conference call to discu...
# 2  ["Given the extensive nature of the text provi...
# 3  ["Danaher Corporation's first quarter 2020 ear...
# 4  ['The Spire Second Quarter Earnings call began...

# %%
# summary_df_chunks['chunks'][0]
# Out:
# '[\'Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0.9% decline in comparable store sales, primarily due to mild winter weather conditions in the Northeast and Midwest. Despite this, the company remains confident in its Monro Forward strategy, which includes store rebranding and re-imaging, technological investments, and optimization of its tire category management.\', "The company\'s store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales. The company has also made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.", \'Monro Inc. has also made significant progress in its acquisitions, with the company announcing the acquisition of three companies with a total of 23 locations. The company expects these acquisitions to add approximately $45 million in annualized sales.\', "The company\'s guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather. The company now expects comparable store sales to be down 1% to flat, with total sales expected to be in the range of $1.027 billion to $1.029 billion.", "The company\'s CEO, Brett Ponton, stated that the company is committed to driving the necessary changes to improve its business and is confident in its ability to execute its strategy. The company\'s CFO, Brian D\'Ambrosia, noted that the company\'s guidance assumes relatively stable overall tire and oil costs for the balance of fiscal 2020.", "During the Q&A session, analysts asked questions about the company\'s store rebranding and re-imaging initiative, its technological investments, and its acquisitions. The company\'s management provided additional color on these topics, including the expected timeline for the rollout of its new tire category management system and the expected impact of the mild winter weather on its business.", "Overall, the company\'s management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders. The company\'s stock price has been impacted by the mild winter weather, but the company\'s management believes that its strategy will ultimately drive growth and profitability.\\n\\nKey points from the call include:", "* Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions.\\n* The company\'s store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales.\\n* The company has made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.", "* The company has announced the acquisition of three companies with a total of 23 locations, which are expected to add approximately $45 million in annualized sales.\\n* The company\'s guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather, with comparable store sales expected to be down 1% to flat and total sales expected to be in the range of $1.027 billion to $1.029 billion.", "Overall, the company\'s management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders."]'

# %%
# len(summary_df_chunks['chunks'][0])
# Out:
# 3452

# %%
# type(summary_df_chunks['chunks'][0])
# Out:
# str

# %%
# len(summary_df_chunks['chunks'][0][0])
# Out:
# 1

# %%
# print(summary_df_chunks['chunks'][0])
# Out:
# ['Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0.9% decline in comparable store sales, primarily due to mild winter weather conditions in the Northeast and Midwest. Despite this, the company remains confident in its Monro Forward strategy, which includes store rebranding and re-imaging, technological investments, and optimization of its tire category management.', "The company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales. The company has also made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.", 'Monro Inc. has also made significant progress in its acquisitions, with the company announcing the acquisition of three companies with a total of 23 locations. The company expects these acquisitions to add approximately $45 million in annualized sales.', "The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather. The company now expects comparable store sales to be down 1% to flat, with total sales expected to be in the range of $1.027 billion to $1.029 billion.", "The company's CEO, Brett Ponton, stated that the company is committed to driving the necessary changes to improve its business and is confident in its ability to execute its strategy. The company's CFO, Brian D'Ambrosia, noted that the company's guidance assumes relatively stable overall tire and oil costs for the balance of fiscal 2020.", "During the Q&A session, analysts asked questions about the company's store rebranding and re-imaging initiative, its technological investments, and its acquisitions. The company's management provided additional color on these topics, including the expected timeline for the rollout of its new tire category management system and the expected impact of the mild winter weather on its business.", "Overall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders. The company's stock price has been impacted by the mild winter weather, but the company's management believes that its strategy will ultimately drive growth and profitability.\n\nKey points from the call include:", "* Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions.\n* The company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales.\n* The company has made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.", "* The company has announced the acquisition of three companies with a total of 23 locations, which are expected to add approximately $45 million in annualized sales.\n* The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather, with comparable store sales expected to be down 1% to flat and total sales expected to be in the range of $1.027 billion to $1.029 billion.", "Overall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders."]

# %% [markdown]
# ### TEXT EMBEDDINGS

# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model_embedding = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embeddings = model_embedding.encode(sentences)
print(embeddings)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [[ 6.76569194e-02  6.34959713e-02  4.87131476e-02  7.93049783e-02
#    3.74480933e-02  2.65277131e-03  3.93749513e-02 -7.09846430e-03
#    5.93614057e-02  3.15369777e-02  6.00981042e-02 -5.29052615e-02
#    4.06067781e-02 -2.59308387e-02  2.98428647e-02  1.12688600e-03
#    7.35148042e-02 -5.03817983e-02 -1.22386612e-01  2.37028562e-02
#    2.97265332e-02  4.24768738e-02  2.56337579e-02  1.99516211e-03
#   -5.69190793e-02 -2.71598026e-02 -3.29035036e-02  6.60248846e-02
#    1.19007230e-01 -4.58791181e-02 -7.26214051e-02 -3.25840116e-02
#    5.23413308e-02  4.50553037e-02  8.25298298e-03  3.67024504e-02
#   -1.39415674e-02  6.53918684e-02 -2.64271945e-02  2.06370896e-04
#   -1.36643145e-02 -3.62810642e-02 -1.95043720e-02 -2.89738011e-02
#    3.94270122e-02 -8.84091184e-02  2.62427772e-03  1.36713730e-02
#    4.83062901e-02 -3.11566498e-02 -1.17329173e-01 -5.11690713e-02
#   -8.85288343e-02 -2.18963325e-02  1.42986095e-02  4.44167666e-02
#   -1.34815648e-02  7.43392259e-02  2.66382862e-02 -1.98763069e-02
#    1.79191381e-02 -1.06052067e-02 -9.04262438e-02  2.13269312e-02
#    1.41204849e-01 -6.47177361e-03 -1.40383979e-03 -1.53609598e-02
#   -8.73571932e-02  7.22174048e-02  2.01402698e-02  4.25588116e-02
#   -3.49013954e-02  3.19520652e-04 -8.02971497e-02 -3.27472612e-02
#    2.85268314e-02 -5.13658151e-02  1.09389201e-01  8.19327757e-02
#   -9.84040201e-02 -9.34096128e-02 -1.51291797e-02  4.51249257e-02
#    4.94172126e-02 -2.51868367e-02  1.57077909e-02 -1.29290730e-01
#    5.31886239e-03  4.02344251e-03 -2.34571658e-02 -6.72982708e-02
#   3.74493049e-03  2.89997254e-02 -1.03952266e-01 -5.85660245e-03
#  -2.43054666e-02 -4.37091626e-02  2.78666168e-02  2.98673213e-02]

# %%
print(embeddings.shape)
# Out:
# (2, 384)

# %%
# Apply text splitting and embeddings to each summary and create a new DataFrame with chunks and embeddings
chunk_data = []

for idx, row in summary_df.iterrows():
    file_id = row['file_id']
    summary = row['summary']
    chunks = text_split(summary)

    for chunk in chunks:
        # Generate embeddings for each chunk
        embedding = model_embedding.encode(chunk)
        chunk_data.append({'file_id': file_id, 'chunk': chunk, 'embedding': embedding})

# Create a new DataFrame with the chunks, embeddings, and file_id
chunks_df = pd.DataFrame(chunk_data)

# %%
chunks_df
# Out:
#      file_id                                              chunk  \
# 0    4320211  Monro Inc. held its third-quarter earnings con...
# 1    4320211  The company's store rebranding and re-imaging ...
# 2    4320211  Monro Inc. has also made significant progress ...
# 3    4320211  The company's guidance for fiscal 2020 has bee...
# 4    4320211  The company's CEO, Brett Ponton, stated that t...
# ..       ...                                                ...
# 180  4360674  4. **M&A Opportunities**: NextEra Energy's CEO...
# 181  4360674  5. **Rate Cases**: NextEra Energy plans to fil...
# 182  4360674  6. **Cost Management**: NextEra Energy has bee...
# 183  4360674  7. **ESG Report**: NextEra Energy will publish...
# 184  4360674  Overall, the conference call highlighted NextE...
#
#                                              embedding
# 0    [0.030996237, 0.007431771, -0.00041755062, 0.0...
# 1    [-0.031461723, -0.025675885, 0.028074343, -0.0...
# 2    [0.050692648, -0.07287536, -0.02692151, -0.042...
# 3    [-0.009417127, 0.008365667, 0.057727903, 0.065...
# 4    [-0.062053658, -0.005355529, 0.004473756, 0.01...
# ..                                                 ...
# 180  [-0.054499786, 0.019563619, 0.013526839, 0.029...
# 181  [-0.059139673, 0.059974324, -0.020970162, 0.00...
# 182  [-0.07092738, 0.088025756, -0.036153235, 0.041...
# 183  [-0.067683294, 0.05618643, -0.030089203, 0.050...
# 184  [-0.09408439, 0.09786645, -0.036906704, 0.0274...
#
# [185 rows x 3 columns]

# %%
# Save the new DataFrame to a CSV file
# Since embeddings are arrays, you may prefer to save the DataFrame as a pickle file instead of CSV
chunks_df.to_pickle('/content/drive/MyDrive/DataSets/Earnings_21_chunks_with_embeddings.pkl')

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index("earningscall")

# %%
# !pip install --upgrade langchain-pinecone
# Out:
# Requirement already satisfied: langchain-pinecone in /usr/local/lib/python3.10/dist-packages (0.1.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.5 in /usr/local/lib/python3.10/dist-packages (from langchain-pinecone) (3.10.3)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /usr/local/lib/python3.10/dist-packages (from langchain-pinecone) (0.2.33)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-pinecone) (1.26.4)
# Requirement already satisfied: pinecone-client<6.0.0,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain-pinecone) (5.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (0.1.99)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain-pinecone) (4.12.2)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (2024.7.4)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (1.0.3)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (4.66.5)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (2.0.7)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-pinecone) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain-pinecone) (2.20.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-pinecone) (3.3.2)

# %%
import pinecone
import uuid
from sentence_transformers import SentenceTransformer
import json

# # Initialize Pinecone
# # Initialize SentenceTransformer model

# Flatten metadata function
def flatten_metadata(metadata):
    """Flatten metadata to simple key-value pairs."""
    flattened = {}
    for key, value in metadata.items():
        if isinstance(value, (str, int, float, bool)):
            flattened[key] = value
        elif isinstance(value, list) and all(isinstance(i, str) for i in value):
            flattened[key] = value
        else:
            # Convert complex structures to JSON strings
            flattened[key] = json.dumps(value)
    return flattened

# %%
def embeddings_of_chunks(chunks):
    embeddings = model_embedding.encode(chunks)
    return embeddings

# %%
# # Generate embeddings
# embeddings = model_embedding.encode(summary_df_chunks['chunks'][0])

# # Prepare the batch of vectors to upsert
# vectors = [(str(uuid.uuid4()), embeddings.tolist(),{
#     "text": summary_df_chunks['chunks'][0],
# })]

# # Upsert to Pinecone
# index.upsert(vectors=vectors)

# %%
chunks_df['embedding'][0]
# Out:
# array([ 3.09962370e-02,  7.43177114e-03, -4.17550618e-04,  1.23695284e-02,
#         4.89719100e-02, -7.71085098e-02, -5.29017709e-02,  4.98609655e-02,
#         2.56649740e-02,  4.41023596e-02,  2.48296615e-02,  3.92573476e-02,
#        -3.87312435e-02, -2.98920628e-02,  2.36047842e-02, -3.87120247e-02,
#        -2.26181429e-02, -1.08925151e-02,  2.53143292e-02,  2.29171682e-02,
#        -5.36330417e-02, -4.80098240e-02,  6.15224382e-03,  2.53079422e-02,
#         8.93436605e-04,  8.35770890e-02, -8.38970765e-02,  2.03637313e-02,
#        -2.45606117e-02, -4.98260036e-02, -2.23936476e-02,  1.11420505e-01,
#         9.01936740e-02, -5.27747609e-02, -6.34396523e-02,  4.97856410e-03,
#         1.64581463e-02, -3.29438597e-02, -1.15038166e-02, -7.15292096e-02,
#        -4.81927842e-02, -5.81656359e-02, -4.67137061e-02, -2.08035763e-02,
#         7.23076090e-02, -2.31149606e-02,  3.29730511e-02,  9.81948823e-02,
#         6.81476220e-02, -1.70236472e-02,  8.76737852e-03, -6.29271567e-02,
#         1.03547364e-01, -2.71813478e-02, -5.87099306e-02,  1.13849536e-01,
#         2.77903583e-03, -7.51536116e-02,  8.59798193e-02,  1.00854901e-03,
#         9.76607352e-02, -8.24695379e-02, -7.38305151e-02,  2.42531840e-02,
#         5.81264235e-02,  1.61865316e-02, -2.57787872e-02, -9.95730236e-03,
#        -1.15523219e-01,  1.91345418e-04,  2.63536535e-02,  3.69683886e-03,
#         2.11235471e-02, -3.35135311e-02, -4.26329263e-02,  2.03899249e-01,
#         1.11423723e-01, -2.02316698e-02,  6.69114804e-03,  1.74109079e-02,
#         4.99385409e-02, -5.19417822e-02,  4.06308062e-02, -7.63582140e-02,
#         1.94642618e-02, -4.82873134e-02,  9.13968682e-02, -5.45962565e-02,
#         1.54631131e-03, -4.43749540e-02, -3.88656706e-02,  6.60785809e-02,
#        -3.44359167e-02, -3.60243991e-02, -5.43905236e-02,  7.22922981e-02,
#         5.07808942e-03,  5.73690422e-03,  1.42052267e-02,  6.01956695e-02,
#         5.13148122e-02,  6.11287616e-02,  4.72462475e-02, -2.37888508e-02,
#        -1.74676981e-02, -1.45851579e-02,  1.45143159e-02,  5.77328503e-02,
#        -9.07521844e-02,  5.24595194e-02, -4.42053527e-02, -9.99616459e-03,
#        -3.90793709e-03,  2.15324052e-02, -3.65905534e-03,  1.95231158e-02,
#        -2.37598959e-02,  1.85185783e-02,  1.95336882e-02, -9.08698887e-03,
#        -2.12161941e-03, -2.59162276e-03, -2.75017098e-02, -9.16489884e-02,
#        -3.05042155e-02, -7.71718547e-02,  7.49611063e-03,  9.11194552e-03,
#         1.15204111e-01, -2.13883724e-02, -2.37776176e-03,  1.66744683e-02,
#        -3.53509635e-02,  2.35774647e-02, -5.63327596e-02,  2.68468615e-02,
#         1.30226305e-02,  1.80582441e-02, -9.27878246e-02,  5.55139035e-02,
#         2.37468146e-02,  1.98454056e-02,  7.55509436e-02, -5.96601851e-02,
#         1.21482741e-02,  4.12666053e-02, -2.40162499e-02, -7.37340674e-02,
#         9.69274119e-02,  3.58926505e-02,  1.91918723e-02,  1.09123122e-02,
#        -4.04172949e-02,  5.85384853e-03, -2.65445672e-02,  7.04268143e-02,
#        -2.06484832e-02, -6.22281656e-02,  1.66858714e-02, -4.29656617e-02,
#         8.44648015e-03,  4.77746613e-02,  3.55723090e-02,  1.75984576e-02,
#        -4.64763166e-03, -4.42381650e-02, -3.45719196e-02, -8.70340616e-02,
#        -1.89970117e-02,  4.95815687e-02,  4.68554907e-02,  1.77737493e-02,
#        -6.44152537e-02,  8.27662721e-02,  1.78194325e-02, -4.18692387e-08,
#         1.63194966e-02,  1.96584370e-02,  5.75418174e-02,  4.11017947e-02,
#         1.18344359e-01,  4.09691706e-02,  8.53745565e-02, -5.97807914e-02,
#         2.88025532e-02,  3.95169370e-02, -1.92618109e-02,  2.83846017e-02,
#        -6.76696077e-02, -2.61273962e-02,  2.87831482e-02, -1.61820594e-02,
#         3.37562035e-03, -3.38600799e-02, -5.00478689e-03, -1.03184126e-01,
#        -1.85179766e-02, -1.45418132e-02,  4.44347709e-02, -3.18779089e-02,
#        -3.61987203e-02, -6.04797713e-02,  2.76331790e-02, -5.68841435e-02,
#         3.99709307e-02, -1.37388306e-02, -1.14953648e-02,  2.22134870e-02,
#         7.91267157e-02,  2.72273570e-02,  2.07343902e-02, -3.27073154e-04,
#        -4.47899848e-03,  4.00507897e-02, -5.72758876e-02,  3.45910788e-02,
#         2.89572421e-02,  5.91907613e-02, -1.02676637e-01,  3.94425318e-02,
#        -7.86783695e-02, -7.23666251e-02, -2.95860786e-02,  3.97594534e-02,
#        -1.39694409e-02, -9.46089327e-02,  6.15522116e-02,  8.52780882e-03,
#         5.07969446e-02,  8.60015526e-02,  2.94951312e-02,  1.21714780e-02,
#        -5.04586287e-02, -4.78997231e-02, -2.26353686e-02,  7.45535120e-02,
#        -3.45488898e-02, -1.44360378e-01, -1.96657963e-02,  2.86137816e-02],
#       dtype=float32)

# %%
len(chunks_df['embedding'][0])
# Out:
# 384

# %%
# # Function to process each row in DataFrame and upload to Pinecone
# def process_and_upload_to_pinecone(df, index):
#     # batch_size = 100  # Define your batch size

#     # Iterate through each row in the DataFrame
#     for _, row in df.iterrows():
#         file_id = row['file_id']
#         text_chunks = row['chunks']  # Chunks are stored as lists
#         # Convert chunks to embeddings and upload to Pinecone

#         # batch = text_chunks[i:i+batch_size]

#         # Generate embeddings
#         embeddings = model_embedding.encode(text_chunks)

#         # Prepare the batch of vectors to upsert
#         vectors = [(str(uuid.uuid4()), embeddings.tolist(), {
#             "text": text_chunks
#         })]

#         # Upsert to Pinecone
#         index.upsert(vectors=vectors)
#         print(f"Uploaded embeddings of file {file_id} to Pinecone.")


#     print("All chunks uploaded to Pinecone.")



# Example usage (assuming Pinecone index is initialized and chunks_df is loaded)
# process_and_upload_to_pinecone(chunks_df, pinecone_index)




# # Convert chunks to embeddings and upload to Pinecone
# batch_size = 100
# for i in range(0, len(text_chunks), batch_size):
#     batch = text_chunks[i:i+batch_size]

#     # Generate embeddings
#     embeddings = model.encode([chunk.page_content for chunk in batch])

#     # Prepare the batch of vectors to upsert
#     vectors = [(str(uuid.uuid4()), embedding.tolist(), {
#         "text": chunk.page_content,
#         **flatten_metadata(chunk.metadata)
#     }) for embedding, chunk in zip(embeddings, batch)]

#     # Upsert to Pinecone
#     index.upsert(vectors=vectors)

# %%
import uuid
import pinecone  # Make sure you have initialized the Pinecone environment and index

# Function to process each row in the DataFrame and upload to Pinecone
def process_and_upload_to_pinecone(df, index):
    # Iterate through each row in the DataFrame
    for _, row in df.iterrows():
        file_id = row['file_id']
        chunk = row['chunk']  # Each chunk is a string
        embedding = row['embedding']  # Embedding stored as a list or array

        # # Convert embedding back to array if it's a string (in case you loaded from CSV)
        # if isinstance(embedding, str):
        #     embedding = list(map(float, embedding.split(',')))

        # Prepare the vector to upsert
        vectors = [(str(uuid.uuid4()), embedding, {"text": chunk})]

        # Upsert to Pinecone
        index.upsert(vectors=vectors)
        print(f"Uploaded chunk of file {file_id} to Pinecone.")

    print("All chunks uploaded to Pinecone.")

# %%
# Example usage with your DataFrame
process_and_upload_to_pinecone(chunks_df, index)
# Out:
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4320211 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4330115 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4341191 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344338 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4344866 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346818 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4346923 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359732 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4359971 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360366 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# Uploaded chunk of file 4360674 to Pinecone.
# All chunks uploaded to Pinecone.

# %%
import pinecone
from sentence_transformers import SentenceTransformer


def query_pinecone(query_text, top_k=5):
    # Generate the embedding for the query text
    query_embedding = model_embedding.encode(query_text).tolist()

    # Query the index
    results = index.query(vector=query_embedding, top_k=top_k, include_metadata=True)

    return results

# Example usage
query = "for Constellium by how much % shipment volumes decreased ?"
results = query_pinecone(query)

# Print results
for match in results['matches']:
    print(f"Score: {match['score']:.2f}")
    print(f"Text: {match['metadata']}")
    print("Other Metadata:", {k:v for k,v in match['metadata'].items() if k != 'text'})
    print("---")
# Out:
# Score: 0.67
# Text: {'text': "Constellium's packaging business was impacted by the pandemic, with shipment volumes down 11% compared to the same quarter last year. However, the company is seeing strong demand in North America and stable demand in Europe. The company's aerospace business was also impacted, with shipment volumes down 40% compared to the same quarter last year."}
# Other Metadata: {}
# ---
# Score: 0.58
# Text: {'text': 'no volume large year were time were logistics back sea profit air volumes only will Air up head was two period half single quarter re half them next can lower for can new also over know low even said for with same full   last back head negative see these has by first air Nagel we was said not large out per out is cargo on are part before it high last much on have single last growth two growth single much sea rate growth, now drop overall some be last were if three same when more   through more'}
# Other Metadata: {}
# ---
# Score: 0.57
# Text: {'text': "Constellium reported its second-quarter earnings, highlighting the company's ability to navigate through the COVID-19 pandemic. The company's shipment volumes decreased by 25% compared to the same quarter last year, and revenue decreased by 33%. However, the company's cost-control measures and flexible business model helped to mitigate the impact of the pandemic."}
# Other Metadata: {}
# ---
# Score: 0.55
# Text: {'text': 'full volume high what these over volume single know than part new two , at second . loss like like will by single part as had single volumes which only, three second volumes large can will which just year much half less also per years during only over out high are of. before volume there high - same with has are   no last sea then year through E cargo be during other we during it in significant even were are much so E next said on see up negative business even much which negative single'}
# Other Metadata: {}
# ---
# Score: 0.55
# Text: {'text': 'Highlight Group but during there units remained steady logistics no single exception due can large first huge profit part sea port overall financial full said volumes performance through loss be reduced re did positive normal below financial port period there two there years months later really came new . well less them K + of can like negative part Nagel much much biggest before Nagel four when due these high drop low + which volume per   , result despite cargo half head freight units it'}
# Other Metadata: {}
# ---

# %%
prompt_template="""
Based on the provided information, please answer the user's question accurately. If the information is insufficient or the answer is unknown, simply respond with "I don't know."

Context: {context}
Question: {question}

Provide a clear and helpful answer below:
Answer:
"""

# %%
PROMPT=PromptTemplate(template=prompt_template, input_variables=["context", "question"])
chain_type_kwargs={"prompt": PROMPT}

# %%
model_Llama = "llama-3.1-70b-versatile"

groq_chat = ChatGroq(groq_api_key=KEY_groq, model_name=model_Llama,temperature=0.25)
llm = groq_chat

# %%
import pinecone
from sentence_transformers import SentenceTransformer
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.schema import BaseRetriever
from langchain.docstore.document import Document
from typing import List

def query_pinecone(query_text, top_k=5):
    # Generate the embedding for the query text
    query_embedding = model_embedding.encode(query_text).tolist()

    # Query the index
    results = index.query(vector=query_embedding, top_k=top_k, include_metadata=True)

    return results

class CustomPineconeRetriever(BaseRetriever):
    def get_relevant_documents(self, query: str) -> List[Document]:
        results = query_pinecone(query)
        docs = []
        for match in results['matches']:
            metadata = match['metadata']
            text = metadata.pop('text', '')  # Remove 'text' from metadata and use it as the main content
            docs.append(Document(page_content=text, metadata=metadata))
        return docs

    async def aget_relevant_documents(self, query: str) -> List[Document]:
        return self.get_relevant_documents(query)

# Initialize the language model
llm = groq_chat

# Set up a custom prompt template
prompt_template="""
Based on the provided information, please answer the user's question accurately. If the information is insufficient or the answer is unknown, simply respond with "I don't know."

Context: {context}
Question: {question}

Provide a clear and helpful answer below:
Answer:
"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

chain_type_kwargs = {"prompt": PROMPT}

# Create the custom retriever
custom_retriever = CustomPineconeRetriever()

# Set up the RetrievalQA chain with the custom retriever
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=custom_retriever,
    return_source_documents=True,
    chain_type_kwargs=chain_type_kwargs
)

# Interactive QA loop
while True:
    user_input = input("Ask a question (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break

    result = qa({"query": user_input})
    print("\nResponse:", result["result"])

    # Optionally, print source documents
    print("\nSource Documents:")
    for doc in result["source_documents"]:
        print(f"- {doc.page_content[:100]}...")  # Print first 100 chars of each source

    print("\n" + "-"*50 + "\n")
# Out:
# Ask a question (or type 'exit' to quit): what did Monro Inc. reported  due to mild winter weather conditions
#
# Response: Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions.
#
# Source Documents:
# - Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0...
# - * Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions...
# - Monro Inc. has also made significant progress in its acquisitions, with the company announcing the a...
# - Steve Rasche presented the company's financial results, including a decline in net economic earnings...
# - The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter wea...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): what did monro incs ceo and cfo stated
#
# Response: Monro Inc.'s CEO, Brett Ponton, stated that the company is committed to driving the necessary changes to improve its business and is confident in its ability to execute its strategy. The company's CFO, Brian D'Ambrosia, noted that the company's guidance assumes relatively stable overall tire and oil costs for the balance of fiscal 2020.
#
# Source Documents:
# - Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0...
# - Monro Inc. has also made significant progress in its acquisitions, with the company announcing the a...
# - * Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions...
# - The company's CEO, Brett Ponton, stated that the company is committed to driving the necessary chang...
# - During the Q&A session, analysts asked questions about the company's cost-control measures, its outl...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): what did monro incs announced about acquisitions
#
# Response: Monro Inc. announced the acquisition of three companies with a total of 23 locations, which is expected to add approximately $45 million in annualized sales.
#
# Source Documents:
# - Monro Inc. has also made significant progress in its acquisitions, with the company announcing the a...
# - Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0...
# - * Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions...
# - During the Q&A session, analysts asked questions about the company's store rebranding and re-imaging...
# - The company's store rebranding and re-imaging initiative has shown promising results, with rebranded...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): exit

# %%
summary_df['summary'][0]
# Out:
# "Monro Inc. held its third-quarter earnings conference call for fiscal 2020. The company reported a 0.9% decline in comparable store sales, primarily due to mild winter weather conditions in the Northeast and Midwest. Despite this, the company remains confident in its Monro Forward strategy, which includes store rebranding and re-imaging, technological investments, and optimization of its tire category management.\n\nThe company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales. The company has also made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.\n\nMonro Inc. has also made significant progress in its acquisitions, with the company announcing the acquisition of three companies with a total of 23 locations. The company expects these acquisitions to add approximately $45 million in annualized sales.\n\nThe company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather. The company now expects comparable store sales to be down 1% to flat, with total sales expected to be in the range of $1.027 billion to $1.029 billion.\n\nThe company's CEO, Brett Ponton, stated that the company is committed to driving the necessary changes to improve its business and is confident in its ability to execute its strategy. The company's CFO, Brian D'Ambrosia, noted that the company's guidance assumes relatively stable overall tire and oil costs for the balance of fiscal 2020.\n\nDuring the Q&A session, analysts asked questions about the company's store rebranding and re-imaging initiative, its technological investments, and its acquisitions. The company's management provided additional color on these topics, including the expected timeline for the rollout of its new tire category management system and the expected impact of the mild winter weather on its business.\n\nOverall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders. The company's stock price has been impacted by the mild winter weather, but the company's management believes that its strategy will ultimately drive growth and profitability.\n\nKey points from the call include:\n\n* Monro Inc. reported a 0.9% decline in comparable store sales due to mild winter weather conditions.\n* The company's store rebranding and re-imaging initiative has shown promising results, with rebranded stores experiencing an 18% increase in sales.\n* The company has made significant progress in its technological investments, including the implementation of a new digital phone and texting system and the development of a cloud-based store staffing and scheduling model.\n* The company has announced the acquisition of three companies with a total of 23 locations, which are expected to add approximately $45 million in annualized sales.\n* The company's guidance for fiscal 2020 has been updated to reflect the impact of the mild winter weather, with comparable store sales expected to be down 1% to flat and total sales expected to be in the range of $1.027 billion to $1.029 billion.\n\nOverall, the company's management expressed confidence in its ability to execute its strategy and drive long-term value for its shareholders."

# %%
import pinecone
from sentence_transformers import SentenceTransformer
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.schema import BaseRetriever
from langchain.docstore.document import Document
from typing import List

def query_pinecone(query_text, top_k=5):
    # Generate the embedding for the query text
    query_embedding = model_embedding.encode(query_text).tolist()

    # Query the index
    results = index.query(vector=query_embedding, top_k=top_k, include_metadata=True)

    return results

class CustomPineconeRetriever(BaseRetriever):
    def get_relevant_documents(self, query: str) -> List[Document]:
        results = query_pinecone(query)
        docs = []
        for match in results['matches']:
            metadata = match['metadata']
            text = metadata.pop('text', '')  # Remove 'text' from metadata and use it as the main content
            docs.append(Document(page_content=text, metadata=metadata))
        return docs

    async def aget_relevant_documents(self, query: str) -> List[Document]:
        return self.get_relevant_documents(query)

# Initialize the language model
llm = groq_chat

# Set up a custom prompt template
prompt_template="""
Based on the provided information, please answer the user's question accurately. If the information is insufficient or the answer is unknown, simply respond with "I don't know."

Context: {context}
Question: {question}

Provide a clear and helpful answer below:
Answer:
"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

chain_type_kwargs = {"prompt": PROMPT}

# Create the custom retriever
custom_retriever = CustomPineconeRetriever()

# Set up the RetrievalQA chain with the custom retriever
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=custom_retriever,
    return_source_documents=True,
    chain_type_kwargs=chain_type_kwargs
)

# Interactive QA loop
while True:
    user_input = input("Ask a question (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break

    result = qa({"query": user_input})
    print("\nResponse:", result["result"])

    # Optionally, print source documents
    print("\nSource Documents:")
    for doc in result["source_documents"]:
        print(f"- {doc.page_content[:100]}...")  # Print first 100 chars of each source

    print("\n" + "-"*50 + "\n")
# Out:
# Ask a question (or type 'exit' to quit): which is second company from start
#
# Response: I don't know.
#
# Source Documents:
# - in after same less has will second there have   first high can less much there significant business ...
# - only business more second out quarter CEO year as just next profit   however even low business less ...
# - freight units it despite are before know growth years next did next came CEO (period market were Sea...
# - The Spire Second Quarter Earnings call began with a welcome from Scott Dudley, Managing Director of ...
# - Those well volumes new it , . - per two they financial still when months Nagel no unit   Sea due can...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): who is ceo of culp inc
#
# Response: Iv Culp is the Chief Executive Officer of Culp, Inc.
#
# Source Documents:
# - Culp, Inc. hosted a conference call to discuss its third quarter 2020 earnings results. The call fea...
# - Culp's global platform is seen as a distinct competitive advantage, allowing the company to quickly ...
# - Culp's expectations for the fourth quarter are subject to a high degree of uncertainty due to the Co...
# - Constellium's CEO also highlighted the company's focus on sustainability, noting that the company ha...
# - Culp expects overall sales to decrease slightly compared to the fourth quarter of last year, with ma...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): and who is cfo for same company
#
# Response: The CFO for the same company is Brian D'Ambrosia.
#
# Source Documents:
# - The company's CEO, Brett Ponton, stated that the company is committed to driving the necessary chang...
# - freight units it despite are before know growth years next did next came CEO (period market were Sea...
# - During the Q&A session, analysts asked questions about the company's cost-control measures, its outl...
# - only business more second out quarter CEO year as just next profit   however even low business less ...
# - 4. **M&A Opportunities**: NextEra Energy's CEO, Jim Robo, expressed interest in pursuing M&A opportu...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): how much loss was reported by culp inc in third quarter
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# <ipython-input-56-21bf1d85ea48> in <cell line: 64>()
#      67         break
#      68
# ---> 69     result = qa({"query": user_input})
#      70     print("\nResponse:", result["result"])
#      71
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     168                 warned = True
#     169                 emit_warning()
# --> 170             return wrapped(*args, **kwargs)
#     171
#     172         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     379         }
#     380
# --> 381         return self.invoke(
#     382             inputs,
#     383             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     162         except BaseException as e:
#     163             run_manager.on_chain_error(e)
# --> 164             raise e
#     165         run_manager.on_chain_end(outputs)
#     166
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     152             self._validate_inputs(inputs)
#     153             outputs = (
# --> 154                 self._call(inputs, run_manager=run_manager)
#     155                 if new_arg_supported
#     156                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     151         else:
#     152             docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 153         answer = self.combine_documents_chain.run(
#     154             input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     155         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     168                 warned = True
#     169                 emit_warning()
# --> 170             return wrapped(*args, **kwargs)
#     171
#     172         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     601
#     602         if kwargs and not args:
# --> 603             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     604                 _output_key
#     605             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     168                 warned = True
#     169                 emit_warning()
# --> 170             return wrapped(*args, **kwargs)
#     171
#     172         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     379         }
#     380
# --> 381         return self.invoke(
#     382             inputs,
#     383             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     162         except BaseException as e:
#     163             run_manager.on_chain_error(e)
# --> 164             raise e
#     165         run_manager.on_chain_end(outputs)
#     166
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     152             self._validate_inputs(inputs)
#     153             outputs = (
# --> 154                 self._call(inputs, run_manager=run_manager)
#     155                 if new_arg_supported
#     156                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/base.py in _call(self, inputs, run_manager)
#     136         # Other keys are assumed to be needed for LLM prediction
#     137         other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 138         output, extra_return_dict = self.combine_docs(
#     139             docs, callbacks=_run_manager.get_child(), **other_keys
#     140         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/combine_documents/stuff.py in combine_docs(self, docs, callbacks, **kwargs)
#     255         inputs = self._get_inputs(docs, **kwargs)
#     256         # Call predict on the LLM.
# --> 257         return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#     258
#     259     async def acombine_docs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     314                 completion = llm.predict(adjective="funny")
#     315         """
# --> 316         return self(kwargs, callbacks=callbacks)[self.output_key]
#     317
#     318     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     168                 warned = True
#     169                 emit_warning()
# --> 170             return wrapped(*args, **kwargs)
#     171
#     172         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     379         }
#     380
# --> 381         return self.invoke(
#     382             inputs,
#     383             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     162         except BaseException as e:
#     163             run_manager.on_chain_error(e)
# --> 164             raise e
#     165         run_manager.on_chain_end(outputs)
#     166
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     152             self._validate_inputs(inputs)
#     153             outputs = (
# --> 154                 self._call(inputs, run_manager=run_manager)
#     155                 if new_arg_supported
#     156                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     774     ) -> LLMResult:
#     775         prompt_messages = [p.to_messages() for p in prompts]
# --> 776         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     777
#     778     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     631                 if run_managers:
#     632                     run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 633                 raise e
#     634         flattened_outputs = [
#     635             LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     621             try:
#     622                 results.append(
# --> 623                     self._generate_with_cache(
#     624                         m,
#     625                         stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     843         else:
#     844             if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 845                 result = self._generate(
#     846                     messages, stop=stop, run_manager=run_manager, **kwargs
#     847                 )
#
# /usr/local/lib/python3.10/dist-packages/langchain_groq/chat_models.py in _generate(self, messages, stop, run_manager, **kwargs)
#     470             **kwargs,
#     471         }
# --> 472         response = self.client.create(messages=message_dicts, **params)
#     473         return self._create_chat_result(response)
#     474
#
# /usr/local/lib/python3.10/dist-packages/groq/resources/chat/completions.py in create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     287           timeout: Override the client-level default timeout for this request, in seconds
#     288         """
# --> 289         return self._post(
#     290             "/openai/v1/chat/completions",
#     291             body=maybe_transform(
#
# /usr/local/lib/python3.10/dist-packages/groq/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1223             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224         )
# -> 1225         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1226
#    1227     def patch(
#
# /usr/local/lib/python3.10/dist-packages/groq/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     918         stream_cls: type[_StreamT] | None = None,
#     919     ) -> ResponseT | _StreamT:
# --> 920         return self._request(
#     921             cast_to=cast_to,
#     922             options=options,
#
# /usr/local/lib/python3.10/dist-packages/groq/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1016
#    1017             log.debug("Re-raising status error")
# -> 1018             raise self._make_status_error_from_response(err.response) from None
#    1019
#    1020         return self._process_response(
#
# InternalServerError: Error code: 503 - {'error': {'message': 'Service Unavailable', 'type': 'internal_server_error'}}

# %%
summary_df['summary'][1]
# Out:
# "Culp, Inc. hosted a conference call to discuss its third quarter 2020 earnings results. The call featured Iv Culp, Chief Executive Officer; Ken Bowling, Chief Financial Officer; and Boyd Chumbley, President of the upholstery fabrics business.\n\nThe company reported a net loss of $5.1 million for the third quarter, compared to a pre-tax income of $4.3 million for the same period last year. The results were affected by a reversal of a $6.1 million recorded contingent earn-out liability and non-cash impairment charges of $13.6 million related to the home accessory division.\n\nCulp's global platform is seen as a distinct competitive advantage, allowing the company to quickly respond to changing market dynamics. The company is also benefiting from significant synergies across its business segments, fostering collaboration and product development.\n\nDespite the challenges in the mattress fabrics business, the company remains focused on creative designs, innovative products, and exceptional service. The upholstery fabrics business was affected by a slowdown in shipments heading into the Chinese New Year holiday, but the company is pleased with its overall performance.\n\nThe home accessories segment, which includes the company's e-commerce and finished products business, reported an operating loss for the quarter. However, the company is encouraged by recent opportunities with new online marketplaces and business-to-business sales channels.\n\nThe company is working to refine its strategy and drive improved results for its home accessories segment. This includes developing new products featuring Culp mattress fabrics and upholstery fabrics, and improving its performance on Amazon.\n\nCulp is also expanding its capabilities in Vietnam and Haiti, with a focus on mattress fabrics and sewn covers. The company expects to add fabric production capabilities in Vietnam this calendar year and is expanding its sewn cover production capabilities in Haiti with a new building and additional equipment.\n\nThe company's outlook for the fourth quarter assumes that the Coronavirus outbreak does not have a greater-than-anticipated impact on its operations. However, the potential impact of the Coronavirus is difficult to estimate reasonably at this point.\n\nCulp expects overall sales to decrease slightly compared to the fourth quarter of last year, with mattress fabric sales expected to be slightly down due to continuing market pressure and softness in its legacy business. Operating income and margins are expected to increase slightly compared to the prior period.\n\nIn the upholstery fabric segment, the company expects fourth-quarter sales and operating income and margins to be slightly higher than the prior year period. In the home accessory segment, the company expects fourth-quarter sales to be comparable to the fourth quarter of last fiscal year, with an operating loss expected but with significant improvement compared to the prior year period.\n\nCulp's expectations for the fourth quarter are subject to a high degree of uncertainty due to the Coronavirus outbreak and its potential impact on consumer confidence and market conditions. The company is closely monitoring the situation and is prepared to adjust its business strategy and operations as needed.\n\nThe call concluded with a question-and-answer session, during which the company's executives provided additional information and insights on its business operations and outlook."

# %%
import pinecone
from sentence_transformers import SentenceTransformer
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.schema import BaseRetriever
from langchain.docstore.document import Document
from typing import List

def query_pinecone(query_text, top_k=5):
    # Generate the embedding for the query text
    query_embedding = model_embedding.encode(query_text).tolist()

    # Query the index
    results = index.query(vector=query_embedding, top_k=top_k, include_metadata=True)

    return results

class CustomPineconeRetriever(BaseRetriever):
    def get_relevant_documents(self, query: str) -> List[Document]:
        results = query_pinecone(query)
        docs = []
        for match in results['matches']:
            metadata = match['metadata']
            text = metadata.pop('text', '')  # Remove 'text' from metadata and use it as the main content
            docs.append(Document(page_content=text, metadata=metadata))
        return docs

    async def aget_relevant_documents(self, query: str) -> List[Document]:
        return self.get_relevant_documents(query)

# Initialize the language model
llm = groq_chat

# Set up a custom prompt template
prompt_template="""
Based on the provided information, please answer the user's question accurately. If the information is insufficient or the answer is unknown, simply respond with "I don't know."

Context: {context}
Question: {question}

Provide a clear and helpful answer below:
Answer:
"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

chain_type_kwargs = {"prompt": PROMPT}

# Create the custom retriever
custom_retriever = CustomPineconeRetriever()

# Set up the RetrievalQA chain with the custom retriever
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=custom_retriever,
    return_source_documents=True,
    chain_type_kwargs=chain_type_kwargs
)

# Interactive QA loop
while True:
    user_input = input("Ask a question (or type 'exit' to quit): ")
    if user_input.lower() == 'exit':
        break

    result = qa({"query": user_input})
    print("\nResponse:", result["result"])

    # Optionally, print source documents
    print("\nSource Documents:")
    for doc in result["source_documents"]:
        print(f"- {doc.page_content[:100]}...")  # Print first 100 chars of each source

    print("\n" + "-"*50 + "\n")
# Out:
# Ask a question (or type 'exit' to quit): what is driving force of danaher corp
#
# Response: The driving force of Danaher Corporation is the Danaher Business System (DBS).
#
# Source Documents:
# - Danaher Corporation's first quarter 2020 earnings conference call took place, led by conference faci...
# - Tom Joyce started by acknowledging the challenges posed by the COVID-19 pandemic and expressing grat...
# - In his final remarks, Joyce reflected on his decision to retire as CEO, effective September 1, 2020,...
# - The company's CEO, Brett Ponton, stated that the company is committed to driving the necessary chang...
# - During the Q&A session, analysts asked questions about the company's decremental margins, cost savin...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): give review of dahher corps first quarter results
#
# Response: I don't know.
#
# Source Documents:
# - best than said high even units big , some out had so half same years during are which last same sing...
# - (Q now drop did like did had due ever Logistics re all only so Sea much are overall   through are sa...
# - just strong at next less next still during volumes first volume these volume full CEO these only las...
# - half by, best good significant new two well not K some a out large them high if like like but from a...
# - there high did high financial them overall three like our ( sea drop now quarter large better growth...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): Danaher Corporation first quarter results
#
# Response: Danaher Corporation's first quarter 2020 earnings conference call provided an update on the company's performance and outlook. However, specific details about the company's first quarter results, such as revenue or earnings per share, are not mentioned in the provided information.
#
# Source Documents:
# - Danaher Corporation's first quarter 2020 earnings conference call took place, led by conference faci...
# - Tom Joyce started by acknowledging the challenges posed by the COVID-19 pandemic and expressing grat...
# - In his final remarks, Joyce reflected on his decision to retire as CEO, effective September 1, 2020,...
# - Joyce also discussed the company's outlook for the second quarter, with core revenue growth expected...
# - The conference call transcript is from Ingersoll Rand's first quarter 2020 earnings call, which took...
#
# --------------------------------------------------
#
# Ask a question (or type 'exit' to quit): exit

# %%
# len(transcript_df['transcription'][2])

# %%
summary_df['summary'][3]
# Out:
# "Danaher Corporation's first quarter 2020 earnings conference call took place, led by conference facilitator Christelle and featuring Tom Joyce, President and CEO, and Matt McGrew, Executive Vice President and CFO. The call began with a welcome and introduction, followed by a review of the company's earnings release, slide presentation, and other relevant materials available on the investor section of the Danaher website.\n\nTom Joyce started by acknowledging the challenges posed by the COVID-19 pandemic and expressing gratitude to Danaher's associates, suppliers, and business partners for their efforts in responding to the crisis. He highlighted the company's position of strength, with a resilient portfolio of businesses, a talented team, and the Danaher Business System (DBS) as its driving force.\n\nJoyce then discussed the company's innovative solutions that are part of the direct response to COVID-19, including IDT's primer and probe kits, Cepheid's rapid molecular test, and Beckman Coulter's antibody assays. He also mentioned the company's support for biotech researchers and manufacturers working on COVID-19 vaccines and therapies, through Pall's filtration solutions and Cytiva's prototype affinity resins.\n\nThe call then shifted to a review of the company's first quarter results, with sales growing 3% to $4.3 billion, driven by 4.5% core revenue growth. The impact of foreign currency translation decreased revenues by 1.5%. Gross profit margin was 56.2%, and operating profit margin was 16.1%. Adjusted diluted net earnings per common share were $1.05.\n\nJoyce also discussed the company's outlook for the second quarter, with core revenue growth expected to be in the range of flat to down 10%. He noted that the company is well-positioned to navigate the uncertain environment, with a strong portfolio, exceptional team, and DBS-driven execution.\n\nThe call concluded with a question-and-answer session, during which Joyce and McGrew addressed various topics, including the company's COVID-19 response, the integration of Cytiva, and the outlook for the environmental and applied solutions segment.\n\nIn his final remarks, Joyce reflected on his decision to retire as CEO, effective September 1, 2020, and expressed confidence in the company's future under the leadership of Rainer Blair, who will succeed him as CEO. Joyce also thanked his colleagues and the Danaher team for their support and hard work over the years.\n\nOverall, the call provided an update on Danaher's performance and outlook, as well as insights into the company's response to the COVID-19 pandemic and its plans for the future."
