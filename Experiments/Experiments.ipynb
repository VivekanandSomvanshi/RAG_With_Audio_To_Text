# %%
import os
import json
import datetime
import pandas as pd
import warnings

# NLP Libraries
import transformers
import torch

import os
import google.generativeai as genai

# Langchain Core
from langchain.schema import HumanMessage, AIMessage, ChatMessage
from langchain_core.tools import tool
from langchain_core.pydantic_v1 import BaseModel, Field

# Langchain LLMs and Agents
from langchain.llms import OpenAI, HuggingFacePipeline, CTransformers
from langchain.chat_models import ChatOpenAI
from langchain.agents import AgentType, load_tools, initialize_agent

# Langchain Chains and Prompts
from langchain.chains import LLMChain, SequentialChain, RetrievalQA, ConversationChain
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate, MessagesPlaceholder
from langchain_core.messages import SystemMessage

# Langchain Memory
from langchain.memory import ConversationBufferMemory, ConversationBufferWindowMemory

# Langchain Document Processing
from langchain.document_loaders import PyPDFLoader, DirectoryLoader, PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Langchain Embeddings and Vector Stores
from langchain.embeddings import HuggingFaceEmbeddings, OpenAIEmbeddings
from langchain.vectorstores import Pinecone

# Groq Integration (if used)
from groq import Groq
from langchain_groq import ChatGroq

# PDF Libraries
import pypdf
from PyPDF2 import PdfReader

# External Libraries
import pinecone
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
KEY_groq = os.getenv('GROQ_API_KEY')
KEY_openai = os.getenv('OPENAI_API_KEY')
KEY_GOOGLE  = os.getenv('GOOGLE_API_KEY')

# %%
from datasets import load_dataset

ds = load_dataset("distil-whisper/earnings21")
# Out:
# Downloading readme: 100%|██████████| 869/869 [00:00<00:00, 2.85kB/s]
# Downloading data: 100%|██████████| 414M/414M [00:32<00:00, 12.6MB/s]
# Downloading data: 100%|██████████| 358M/358M [00:19<00:00, 18.0MB/s]
# Generating test split: 100%|██████████| 44/44 [00:04<00:00, 10.81 examples/s]

# %%
ds
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['audio', 'file_id', 'audio_length', 'sample_rate', 'company_name', 'financial_quarter', 'sector', 'speaker_switches', 'unique_speakers', 'curator_id', 'transcription'],
#         num_rows: 44
#     })
# })

# %%
test_df = pd.read_csv('DATA\Earnings_21.csv')

# %%
test_df
# Out:
#     file_id  audio_length  sample_rate                          company_name  \
# 0   4320211      3285.848        24000                             Monro Inc
# 1   4330115      2458.904        24000                              Culp Inc
# 2   4341191      5740.640        24000                      General Electric
# 3   4344338      2721.169        44100                          Danaher Corp
# 4   4344866      3275.456        24000                             Spire Inc
# 5   4346818      3972.022        11025                        Ingersoll Rand
# 6   4346923      4709.418        16000                        Cementos Argos
# 7   4359732      4887.498        44100            Kuehne Nagel International
# 8   4359971      3759.944        24000                           Constellium
# 9   4360366      3906.752        24000               Travelers Companies Inc
# 10  4360674      3595.023        11025                    Nextera Energy Inc
# 11  4360717      4511.312        24000            Fomento Economico Mexicano
# 12  4361631      4411.446        22050                                Enagas
# 13  4363614      5586.921        11025                       Banco Santander
# 14  4364366      3506.050        11025                        Mosaic Company
# 15  4365024      4328.676        16000                    Nextar Media Group
# 16  4365948      2519.009        22050              GCP Applied Technologies
# 17  4366302      3595.049        44100              Healthcare Realty Trusts
# 18  4366429      4010.929        44100                 Dentsply Sironas XRay
# 19  4366522      1817.901        22050              Aldeyra Therapeutics Inc
# 20  4366893      2366.394        16000                 Earthstone Energy Inc
# 21  4367318      1720.832        24000            AcelRX Pharmaceuticals Inc
# 22  4367535      3175.328        24000                               Affimed
# 23  4368670      4222.006        22050                RWE Aktiengesellschaft
# 24  4374910      2028.536        24000              American Express Company
# 25  4375653      3472.184        24000                              Illumina
# 26  4382825      3795.147        44100                        Conocophillips
# 27  4383161      3376.712        24000                   Pilgrims Pride Corp
# 28  4384198      2636.382        44100                  New Home Company Inc
# 29  4384683      1476.776        24000                           One Gas Inc
# 30  4384744      3272.000        16000                            Adtran Inc
# 31  4384964      4022.624        24000                            Eversource
# 32  4385072      2560.008        24000                           Sitime Corp
# 33  4385388      4346.451        44100                         Yeti Holdings
# 34  4385939      3049.832        24000                       Hershey Company
# 35  4386541      1097.100        16000                     Cumulus Media Inc
# 36  4387332      1310.192        24000                              Zagg Inc
# 37  4387383      2158.072        22050                    Clipper Realty Inc
# 38  4387865      2162.637        11025                          Indentiv Inc
# 39  4389907      2058.848        24000                 Pheonix New Media Ltd
# 40  4392809      1438.040        24000                         Lands End Inc
# 41  4394084      1758.024        16000  Innovative Solutions and Support Inc
# 42  4397800      2771.672        24000                         Rev Group Inc
# 43  4397829      4472.768        24000               Bed Bath and Beyond Inc
#
#     financial_quarter            sector  speaker_switches  unique_speakers  \
# 0                   3    Consumer Goods                82               10
# 1                   3  Industrial Goods                43                8
# 2                   1      Conglomerate               147               14
# 3                   1      Conglomerate                51                7
# 4                   2         Utilities                82               10
# 5                   1  Industrial Goods                99               14
# 6                   1  Industrial Goods               120               20
# 7                   2          Services               114               13
# 8                   2  Industrial Goods               116               10
# 9                   2         Financial               104               15
# 10                  2         Utilities                43                9
# 11                  2    Consumer Goods               120               15
# 12                  2         Utilities                28               12
# 13                  2         Financial                68               17
# 14                  2   Basic Materials                97                6
# 15                  2          Services               105               13
# 16                  2   Basic Materials                42                6
# 17                  2         Financial                93               15
# 18                  2        Healthcare                78               13
# 19                  2        Healthcare                22                5
# 20                  2   Basic Materials                51                9
# 21                  2        Healthcare                37                7
# 22                  2        Healthcare                54               11
# 23                  2         Utilities                95               15
# 24                  3         Financial                56                2
# 25                  3        Healthcare                32               10
# 26                  3   Basic Materials                91               18
# 27                  3    Consumer Goods                57               11
# 28                  3  Industrial Goods                60                9
# 29                  3   Basic Materials                31                8
# 30                  3        Technology                86                9
# 31                  3         Utilities               112               15
# 32                  3        Technology                61               10
# 33                  3    Consumer Goods                67               12
# 34                  3    Consumer Goods               132               19
# 35                  3          Services                17                5
# 36                  3          Services                27                6
# 37                  3         Financial                56               10
# 38                  3        Technology                50                5
# 39                  3        Technology                24                7
# 40                  3          Services                26                6
# 41                  4        Technology                41                6
# 42                  4      Conglomerate                68                9
# 43                  3      Conglomerate                77               15
#
#     curator_id                                      transcription
# 0            1  Good morning ladies and gentlemen, and welcome...
# 1            1  Good day and welcome to Culp's third quarter 2...
# 2            1  Good morning and welcome to the first quarter ...
# 3            1  My name is Christelle and I will be your confe...
# 4            8  Good morning, and welcome to the Spire Second ...
# 5            0  Ladies and gentlemen thank you for standing by...
# 6            1  Hello gentlemen, gent- ladies and gentlemen, a...
# 7            9  Ladies and gentlemen, welcome to Kuehne + Nage...
# 8            8  Ladies and gentlemen, thank you for standing b...
# 9            8  Good morning, ladies and gentlemen. Welcome to...
# 10           8  Good morning everyone, and welcome to the Next...
# 11           8  Please stand by. Good morning, and welcome, ev...
# 12           1  Good morning, ladies and gentlemen. Be very we...
# 13           1  Good day everyone, and welcome to Banco Santan...
# 14           8  Good morning, ladies and gentlemen. And welcom...
# 15           8  Then I must go to the Nexstar Media Group's se...
# 16           8  Good morning and welcome to the GCP Applied Te...
# 17           8  Good day, and welcome to the Healthcare Realty...
# 18           8  Ladies and gentlemen, thank you for standing b...
# 19           1  Ladies and gentlemen, thank you for standing b...
# 20           2  Good morning, and welcome to Earthstone Energy...
# 21           1  Welcome to the AcelRx Second Quarter 2020 conf...
# 22           3  Good day, and welcome to the Affimed second qu...
# 23           3  Welcome to the RWE conference call. Markus Kre...
# 24           1  Good morning. This is Craig Moore with Autonom...
# 25           8  Ladies and gentlemen, thank you for standing b...
# 26           9  Good morning, and welcome to Q3 2020 ConocoPhi...
# 27           9  Good morning and welcome to the third quarter ...
# 28           4  Greetings, and welcome to the New Home Company...
# 29           9  Good day and welcome to the ONE Gas Third Quar...
# 30           4  Ladies and gentlemen, thank you for standing b...
# 31           4  Welcome to the Eversource Energy Q3 2020 Resul...
# 32           5  Good afternoon and welcome to SiTimes third qu...
# 33           9  Greetings, and welcome to the YETI Third Quart...
# 34           9  Greetings, and welcome to the Hershey Company ...
# 35           6  Welcome to the Cumulus Media quarterly earning...
# 36           6  Ladies and gentlemen, thank you for standing b...
# 37           6  Welcome to the Compumedics audio conferencing ...
# 38           3  Good afternoon. Welcome to Identiv's presentat...
# 39           3  Ladies and gentlemen, thank you for standing b...
# 40           3  Ladies and gentlemen, thank you for standing b...
# 41           7  Welcome to the Innovative Solutions and Suppor...
# 42           7  Wow. Are you <inaudible>. Yeah. Greetings, and...
# 43           7  Welcome to the Bed Bath and Beyond fiscal 2020...

# %% [markdown]
# #### Saving audiofiles to .mp3 format

# %%
import soundfile as sf
import os

for i in range(10):
  audio_data = ds['test'][i]['audio']
  # Extract the audio data
  audio_samples = audio_data['array']
  sample_rate = audio_data['sampling_rate']

  # Specify the output file path in your working directory
  output_filename = os.path.join('/content/', f'output_audio_{i}.mp3')

  # Save the audio file
  sf.write(output_filename, audio_samples, sample_rate)

  print(f"Audio saved as {output_filename}")

# %%
import soundfile as sf
import os

audio_data = ds['test'][41]['audio']
# Extract the audio data
audio_samples = audio_data['array']
sample_rate = audio_data['sampling_rate']

# Specify the output file path in your working directory
output_filename = 'output_audio_{41}.mp3'

# Save the audio file
sf.write(output_filename, audio_samples, sample_rate)

print(f"Audio saved as {output_filename}")
# Out:
# Audio saved as output_audio_{41}.mp3

# %%
import soundfile as sf
import os

audio_data = ds['test'][10]['audio']
# Extract the audio data
audio_samples = audio_data['array']
sample_rate = audio_data['sampling_rate']

# Specify the output file path in your working directory
output_filename = 'output_audio_10.mp3'

# Save the audio file
sf.write(output_filename, audio_samples, sample_rate)

print(f"Audio saved as {output_filename}")
# Out:
# Audio saved as output_audio_10.mp3

# %%
import soundfile as sf
import os

audio_data = ds['test'][11]['audio']
# Extract the audio data
audio_samples = audio_data['array']
sample_rate = audio_data['sampling_rate']

# Specify the output file path in your working directory
output_filename = 'output_audio_11.mp3'

# Save the audio file
sf.write(output_filename, audio_samples, sample_rate)

print(f"Audio saved as {output_filename}")
# Out:
# Audio saved as output_audio_11.mp3

# %%
import soundfile as sf
import os

audio_data = ds['test'][12]['audio']
# Extract the audio data
audio_samples = audio_data['array']
sample_rate = audio_data['sampling_rate']

# Specify the output file path in your working directory
output_filename = 'output_audio_12.mp3'

# Save the audio file
sf.write(output_filename, audio_samples, sample_rate)

print(f"Audio saved as {output_filename}")
# Out:
# Audio saved as output_audio_12.mp3

# %%
import soundfile as sf
import os

audio_data = ds['test'][13]['audio']
# Extract the audio data
audio_samples = audio_data['array']
sample_rate = audio_data['sampling_rate']

# Specify the output file path in your working directory
output_filename = 'output_audio_13.mp3'

# Save the audio file
sf.write(output_filename, audio_samples, sample_rate)

print(f"Audio saved as {output_filename}")
# Out:
# Audio saved as output_audio_13.mp3

# %%
import os
from groq import Groq

# Set up the Groq API client
KEY_groq = os.getenv('GROQ_API_KEY')  # Ensure your API key is set in the environment
client = Groq(api_key=KEY_groq)

# %%
def transcribe_audio(filename):
    with open(filename, "rb") as file:
        transcription = client.audio.transcriptions.create(
            file=(filename, file.read()),
            model="whisper-large-v3",
            temperature=0.31,
            language="en",
            response_format="verbose_json",
        )
    return transcription  

# Assuming the transcription result contains a 'text' key

# %%
# Full directory path to the audio files
base_path = r"C:\Users\somva\Documents\Work\Earnings_21_RAG\RAG_With_Audio_To_Text\DATA"

# List of audio files with the full path
audio_files = [os.path.join(base_path, f"output_audio_{i}.mp3") for i in range(11)]


# Dictionary to store transcriptions
transcripts_dict = {}

for filename in audio_files:
    transcript = transcribe_audio(filename)
    transcripts_dict[filename] = transcript

# %%
transcripts_dict
# Out:
# {}

# %%
for filename, transcript in transcripts_dict.items():
    print(f"Transcription for {filename}:")
    print(transcript)
    print("\n" + "="*50 + "\n")
